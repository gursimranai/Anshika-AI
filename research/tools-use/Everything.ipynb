# %% [markdown]
# ## Version 0.1
#
# - **pyttsx3:** pyttsx is a cross-platform text to speech library which is platform-independent. The major advantage of using this library for text-to-speech conversion is that it works offline.
#
# - **SpeechRecognition:** This allows us to convert audio into text for further processing.
#
# - **pywhatkit:** This is an easy-to-use library that will help us interact with the browser very easily.
#
# - **wikipedia:** We'll use this to fetch a variety of information from the Wikipedia website.
#
# - **requests:** This is an elegant and simple HTTP library for Python that allows you to send HTTP/1.1 requests extremely easily.
#
# - **python-decouple:** To use the contents from the .env file, we'll install another module called python-decouple.
#
# - **Many-Other-Libraries**
#
# - **gTTS (Google Text-to-Speech):** Creates natural-sounding voice replies online.
#
# - **pygame:** Plays audio files and sound effects smoothly.
#
# - **pyaudio:** Records audio through your microphone.
#
# - **pvporcupine:** Listens for a custom wake-word like "Jarvis" efficiently.
#
# - **pyautogui:** Controls your mouse and keyboard to open apps or click buttons.
#
# - **psutil:** Checks your CPU, battery, and memory usage.
#
# - **comtypes:** Accesses Windows system commands and settings.
#
# - **requests:** Fetches live weather, news, and web data via APIs.

# %% [markdown]
# # Core-Processing
#
# - **Lang-chain**
# - **llama-index**
# - **openai**
# - **google-generativeai**
# - **transformers**
#
#
# ---

# %% [markdown]
# * **opencv-python**: Captures real-time webcam video feeds for object tracking.
# * **face-recognition**: Identifies your face for secure biometric system login.
# * **mediapipe**: Tracks complex hand gestures for touchless wave controls.
#
# * **elevenlabs**: Generates hyper-realistic, human-like voice outputs.
# * **cohere**: Powers advanced conversational nuance and text intent generation.
# * **webrtcvad**: Detects voice activity silence to automatically stop microphone recording.
# * **sounddevice**: Records low-latency, high-quality microphone audio natively.
#
#
# * **homeassistant-api**: Links Jarvis to your local smart home ecosystem and devices.
# * **pychromecast**: Streams multimedia content directly to TVs and smart speakers.
#
#
# * **os / subprocess**: Built-in core modules to launch local PC apps and video games.
# * **beautifulsoup4**: Scrapes quick web data like live news or local weather.
# * **selenium**: Automates browser actions, clicks, and secure form logins.
# * **playwright**: Runs ultra-fast, modern browser automation entirely in the background.
#
#
# * **apscheduler**: Manages timed alarms, daily reminders, and routine scripts.
# * **sqlite3**: Stores local user preferences and heavy conversation logs safely.
#
#
# * **customtkinter**: Creates a sleek, modern, dark-themed system application window.
# * **flet**: Builds smooth, Flutter-style cross-platform desktop interfaces using Python.
#
# ⏳ [SYSTEM]: Processing intent matrix...
